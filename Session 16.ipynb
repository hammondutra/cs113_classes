# %%
# Write T(e_1) as a vector object
"""
To find the matrix that represents this linear mapping, we:
1) Verify that we have a linear transformation by checking if it is (a) closed under vector addition and (b) scalar multiplication:
Let u = (u1, u2) and v = (v1, v2)

# Checking if it is closed under vector addition: L(u + v) = L(u) + L(v)
L(u + v) = L([u1 + v1, u2 + v2]) = (2u2 + 2v2, -2u1 - 2v1)
L(u) + L(v) = L([u1, u2]) + L([v1, v2]) = (2u2, -2u1) + (2v2, -2v1) = (2u2 + 2v2, -2u1 -2v1)

Because L(u + v) = L(u) + L(v) holds, the first property is satisfied

# Checking if it is closed under scalar multiplication:
L(Ku) = L(Ku1, Ku2) = (2Ku2, -2Ku1) = K*L(u)

Because L(Ku) = KL(u) holds, the second property is satisfied

Conclusion: The transformation corresponds to a linear mapping!

2) Determine the dimensions of A: 2x2 (2 is the input and output size because T: R^2 -> R^2)

3) Establish the basis of our input (generally, we prefer to use the standard basis vectors to make calculations easier):
Use standard basis vectors: e1 = (1, 0), e2 = (0, 1)

4) Then, we compute the transformations of each of our basis vectors:
T(e1) = (0, -2)
T(e2) = (2, 0)

We lastly set up our matrix A from these transformed basis vectors:
[  |   | ]
[ e1, e2 ]
[  |   | ]

[ 0,   2]
[ -2,  0]
A = [(0, -2), (2, 0)]
"""

answer = vector([0, -2])

# %%
# Write T(e_2) as a vector object

answer = vector([2, 0])

# %%
# Write your answer as a matrix object
"""
[ 0, -2]
[ 2,  0]
"""

answer = matrix(QQ, [[0, 2],
                     [-2, 0]])

# %%
"""
Write your answer as a matrix object.
# The resolution below is from the exercise (a)
var("a, b, c, d, x")
left_side = (((a + c)*x)^2 + 2*((a + c)(b + d)*x) + (b + d)^2).full_simplify()
print(left_side)

right_side = ((a*x + b)^2 + (c*x + d)^2).full_simplify()
print(right_side)

print(bool(left_side == right_side)) # Prints false

# The resolution below is from the exercise (b)

To find the matrix that represents this linear mapping, we:
1) Verify that we have a linear transformation by checking if it is (a) closed under vector addition and (b) scalar multiplication:
Let u = (u1, u2) and v = (v1, v2)

# Checking if it is closed under vector addition: L(u + v) = L(u) + L(v)
L(u + v) = L([u1 + v1, u2 + v2]) = (u1 + v1 - u2 - v2, 3u2 + 3v2, 4u1 + 4v1 + 5u2 + 5v2) # Left side
L(u) + L(v) = L([u1, u2]) + L([v1, v2]) = (u1 - u2, 3u2, 4u1 + 5u2) + (v1 - v2, 3v2, 4v1 + 5v2) = (u1 + v1 - u2 - v2, 3u2 + 3v2, 4u1 + 4v1 + 5u2 + 5v2)

Because L(u + v) = L(u) + L(v) holds, the first property is satisfied

# Checking if it is closed under scalar multiplication:
L(Ku) = L(Ku1, Ku2) = (K(u1 - u2), K(3u2), K(4u1 + 5u2)) = K*L(u)

Because L(Ku) = KL(u) holds, the second property is satisfied

Conclusion: The transformation corresponds to a linear mapping!

2) Determine the dimensions of A: 3x2 (2 is the input and output size because T: R^2 -> R^3)

3) Establish the basis of our input (generally, we prefer to use the standard basis vectors to make calculations easier):
Use standard basis vectors: e1 = (1, 0), e2 = (0, 1)

4) Then, we compute the transformations of each of our basis vectors:
T(e1) = (1, 0, 4)
T(e2) = (-1, 3, 5)

We lastly set up our matrix A from these transformed basis vectors:
[  |   | ]
[ e1, e2 ]
[  |   | ]

[ 1, -1]
[ 0,  3]
[ 4,  5]

A = [(1, -1), (0, 3), (4, 5)]
"""


answer = matrix([[1, -1],
                 [0,  3],
                 [4,  5]])
